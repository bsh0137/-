# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/fund/fundDetail.nhn?fundCd=KR522368350"
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')

print(soup)
# Out:
# <script language="javascript" src="/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=fund&amp;submenu=fundend"></script>
# <script src="/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <div class="detail" id="container">
# <script language="JavaScript" src="/js/flashObject.js?20200107172122"></script>
# <div class="h_company">
# <h2 alt="" title=""></h2>
# <div class="description">
# <span class="code"></span>
# <em class="summary summary_v2">
# <a href="#" onclick="return false;" onmouseout="hideLayer('summary_lyr');" onmouseover="showLayer('summary_lyr');"></a>
# <span class="blind">기업개요</span>
# <div class="summary_lyr" id="summary_lyr" style="display: none; top: 19px; left: -320px;">
# <div class="summary_info" id="summary_info">
# <p><strong>단축코드란,자산운용협회가 모든 집합투자기구에 부여하는 표준코드 중 유일성이 부여된 5자리 코드를 말한다.</strong><br/>
# 							1996년을 기점으로 운용 중이거나 신규로 설정되는 모든 간접투자기구에 표준코드를 부여하고 있으며, 표준코드는 협회규정기준<br/>
# ...

# %%
price_tbl = soup.find_all(class_="tbl_fund")
X = price_tbl.find_all("tbody")
print(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-4d6cdb30b57c> in <module>
#       1 price_tbl = soup.find_all(class_="tbl_fund")
# ----> 2 X = price_tbl.find_all("tbody")
#       3 print(X)
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
price_tbl = soup.find_all('table',{'class':tbl_fund})
print(price_tbl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-764e9130a7e8> in <module>
# ----> 1 price_tbl = soup.find_all('table',{'class':tbl_fund})
#       2 print(price_tbl)
#
# NameError: name 'tbl_fund' is not defined

# %%
    ex_id_divs = soup.find('div', {'id' : 'ex_id'})
